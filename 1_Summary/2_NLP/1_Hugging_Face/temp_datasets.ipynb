# %% [markdown]
# # Remove/select columns.

# %%
ds.remove_columns(['cola', 'colb'])
ds.select_columns(['cola', 'colb'])

# %% [markdown]
# # train_test_split.

# %%
val_size = 0.2

# DOES NOT WORK. train_test_split is designed for like df, not ds.
train_ds, valid_ds = train_test_split(train_ds, test_size=val_size)  

# Try ds.train_test_split(test_size) instead.
split    = train_ds.train_test_split(test_size=val_size)
train_ds = split['train']
valid_ds = split['test']
